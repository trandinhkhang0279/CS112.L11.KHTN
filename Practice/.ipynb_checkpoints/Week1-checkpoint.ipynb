# %% [markdown]
# ### 1. Abstraction:

# %% [markdown]
# Tìm dãy con liên tiếp có tổng lớn nhất trong dãy a có n số nguyên ( $1 \le n \le 10^6, 0 \le \mid a_i \mid \le 10^9, i = [1,n] $ )

# %% [markdown]
# ### 2. Pattern Recognition:

# %% [markdown]
# Viet cai gi day

# %% [markdown]
# ### 3. Algorithm designed

# %% [markdown]
# ### 4. Programming

# %%
print("Hello Tri")
# Out:
# Hello Tri

# %%
n = int(input())
a = list(map(int, input().split()))

m = 0
sum = 0
b = [[0, 0]]
p, q = 0, 0
_p, _q = 0, 0
for i in range(n):
    sum += a[i]
    if sum <= 0:
        sum = 0
        p = i + 1
        q = i + 1
    if sum > m:
        m = sum
        _p, _q = p, i
    elif sum == m and p < _p:
        _p, _q = p, q
print(str(_p + 1) + " " + str(_q + 1) + " " + str(m))
# Out:
# 5 15 12
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-3ecba78f7fb4> in <module>
# ----> 1 n = int(input())
#       2 a = list(map(int, input().split()))
#       3
#       4 m = 0
#       5 sum = 0
#
# ValueError: invalid literal for int() with base 10: '5 15 12'
