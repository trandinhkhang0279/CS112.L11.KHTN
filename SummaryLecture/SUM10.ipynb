# %% [markdown]
# <a href="https://colab.research.google.com/github/trandinhkhang0279/CS112.L11.KHTN/blob/Vutd/SummaryLecture/SUM10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nhóm N012 ([Chi tiết tại đây](https://github.com/trandinhkhang0279/CS112.L11.KHTN/blob/master/README.md))

# %% [markdown]
# ###TÓM TẮT BÀI GIẢNG BUỔI 10

# %% [markdown]
# 1. Các nội dung đã thực hiện trong buổi học:
# - Tự tìm hiểu và làm 4 bài tập trong UIT ALGO BOOTCAMP
#     - Định lý Ferma lớn
#     - Dây chuyền
#     - Thông báo
#     - Dung dịch sát trùng
#
# 2. Các nội dung lí thuyết và bài tập trọng tâm của buổi học:
# - Không có thuyết trình
#
# 3. Các nội dung khác:
# - Không có
